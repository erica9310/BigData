# %%
#import mymodule.naver_api_caller3 as caller3 폴더명.파일이름 as 닉네임생성

# %%
import mymodule.naver_api_crawler as crawler

# %%
result1 = crawler.get1000Result("강남역 맛집")
result1
# Out:
# <Response [200]>
# [{'bloggerlink': 'http://blog.naver.com/talk442',
#   'bloggername': '비키의 소소한일상:)',
#   'description': '찾다가<b>강남역 맛집</b> 중 102J라는 곳이 눈에 띄더라고요. 후기를 보니 민트민트하고 고급스러운게 딱 언니들 취향이라 단톡방에 여기를 가자고 했더니 다들 찬성을 해서 만장일치로 결정을 했어요. 처음에는 강남... ',
#   'link': 'http://blog.naver.com/talk442?Redirect=Log&amp;logNo=221439805503',
#   'postdate': '20190111',
#   'title': '<b>강남역 맛집</b> 여자들이 좋아할만해!'},
#  {'bloggerlink': 'http://blog.naver.com/kwoncharm_e',
#   'bloggername': '권매력의 charming-DAY',
#   'description': '<b>강남역 맛집</b> 숨어있는 핫플 목적지로 가는 길에 간판이 보이길래 한장 찍어보았다. 외관이 굉장히... 이른 시간에 손님들이 나오는 게 아무래도 많은 분들이 자주 이용하는 맛집인 거 같다. 출입문도 굉장히 넓은... ',
#   'link': 'http://blog.naver.com/kwoncharm_e?Redirect=Log&amp;logNo=221433940140',
#   'postdate': '20190104',
#   'title': '<b>강남역 맛집</b> 숨어있는 핫플'},
#  {'bloggerlink': 'http://blog.naver.com/llillo2',
#   'bloggername': '우기부기블로그',
# ...

# %%
result2 = crawler.get1000Result("강남역 카페")
result2
# Out:
# <Response [200]>
# [{'bloggerlink': 'http://blog.naver.com/el512',
#   'bloggername': '허브향 가득 퀘럼네 베란다정원',
#   'description': '최근에 친한 언니들과 강남 쪽에서 만나서 수다를 떨만한 카페를 찾다가 강남역 디저트 카페를... 그렇게 가게 된 <b>강남역 카페</b>였어요. 뭐 나중에 알고보니 강남역은 지점이고 신사동에 본점이 있었지만... ',
#   'link': 'http://blog.naver.com/el512?Redirect=Log&amp;logNo=221414133393',
#   'postdate': '20181207',
#   'title': '<b>강남역</b> 디저트 <b>카페</b> 풍미 가득 카라멜, 마망갸또'},
#  {'bloggerlink': 'http://blog.naver.com/dmsp3535',
#   'bloggername': "GRACE's lov diary",
#   'description': '궁금하시면 드셔 보시는 것도 좋을 거 같아요~ 그레이스케일 커피 그리고 밥먹으면 바로 카페 가야죠... 맛있었어요 강남역 맛집, <b>강남역 카페</b> 이번엔 둘다 그렇게 만족스럽진 않았는데 아시죠 그래도 다 먹긴... ',
#   'link': 'http://blog.naver.com/dmsp3535?Redirect=Log&amp;logNo=221440499654',
#   'postdate': '20190112',
#   'title': '<b>강남역</b> 맛집 + <b>카페</b> 데이트, 핫한 곱창쌀국수 &quot;땀땀&quot; 후기'},
#  {'bloggerlink': 'http://blog.naver.com/stopper123',
#   'bloggername': 'viviant:)비비앙뜨',
# ...

# %%
import json

# %%
list = []
list = result1 + result2

# %%
file = open("./gangnam2.json", "w+")
file.write(json.dumps(list))
# Out:
# 177373
