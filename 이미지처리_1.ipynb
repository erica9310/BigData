# %% [markdown]
# <a href="https://colab.research.google.com/github/erica9310/BigData/blob/master/%EC%9D%B4%EB%AF%B8%EC%A7%80%EC%B2%98%EB%A6%AC_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q mahotas

# %%
import mahotas as mh

# %%
from matplotlib import pyplot as pt

# %%
# %matplotlib inline

# %%
image = mh.imread('2018102001169_0.jpg')

# %%
pt.figure(figsize=(8,8))
#pt.imszxhow(image) 옛날 버전 함수
pt.imshow(image)
pt.show()
